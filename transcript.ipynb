# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd
import json 
from langchain.embeddings import OpenAIEmbeddings
from langchain.indexes import  VectorstoreIndexCreator
from langchain.document_loaders import TextLoader, DirectoryLoader
from langchain.llms import OpenAI
import os

# %%
video_links = ["9lVj_DZm36c", "ZUN3AFNiEgc"]

if os.path.exists('transcripts'):
    print('Directory already exists')
else:
    os.mkdir('transcripts')
for video_id in video_links:
    dir = os.path.join('transcripts', video_id)
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    print(transcript)
    # df = pd.DataFrame.from_records(transcript)
    # print(df)
    with open(dir+'.txt', 'w') as f:
        for line in df['text']:
            f.write(f"{line}\n")
# Out:
# Directory already exists
# [{'text': 'all right guys hardest part of the video', 'start': 0.08, 'duration': 2.96}, {'text': "we're getting it right out right out of", 'start': 1.68, 'duration': 3.36}, {'text': 'the gate i need to say the name of this', 'start': 3.04, 'duration': 4.64}, {'text': 'laptop correctly this sponsored by', 'start': 5.04, 'duration': 3.92}, {'text': 'lenovo of course', 'start': 7.68, 'duration': 5.2}, {'text': 'is the lenovo slim 7i pro x not the yoga', 'start': 8.96, 'duration': 7.36}, {'text': 'it is in europe but not here', 'start': 12.88, 'duration': 5.52}, {'text': 'the charger that we get is a hundred', 'start': 16.32, 'duration': 4.719}, {'text': 'watts over usb type-c really like to see', 'start': 18.4, 'duration': 4.24}, {'text': 'it i thought at first when i saw that it', 'start': 21.039, 'duration': 3.601}, {'text': "was yellow it was lenovo's little", 'start': 22.64, 'duration': 3.84}, {'text': 'proprietary charger which also in', 'start': 24.64, 'duration': 3.6}, {'text': 'fairness is pretty good all right what', 'start': 26.48, 'duration': 5.119}, {'text': 'else do we have in here', 'start': 28.24, 'duration': 6.72}, {'text': 'it says yoga rate on it', 'start': 31.599, 'duration': 4.96}, {'text': "the good news is it's a good feeling", 'start': 34.96, 'duration': 3.599}, {'text': 'laptop having a look at the i o here you', 'start': 36.559, 'duration': 4.16}, {'text': 'get two thunderbolt 4 ports and you', 'start': 38.559, 'duration': 3.84}, {'text': 'might want to use those for display as', 'start': 40.719, 'duration': 3.84}, {'text': 'well because the hdmi we have right here', 'start': 42.399, 'duration': 5.441}, {'text': "is only 2.0 not 2.1 so if you're hooking", 'start': 44.559, 'duration': 5.041}, {'text': 'up to 4k display and just use', 'start': 47.84, 'duration': 3.52}, {'text': 'thunderbolts over on the other side we', 'start': 49.6, 'duration': 4.4}, {'text': 'have a full size usb type a headphone', 'start': 51.36, 'duration': 6.08}, {'text': 'microphone combo and oh a little webcam', 'start': 54.0, 'duration': 5.84}, {'text': "disabled i'd like to see that overall", 'start': 57.44, 'duration': 4.88}, {'text': 'though this is um a very laptop looking', 'start': 59.84, 'duration': 4.959}, {'text': 'laptop what i am impressed with though', 'start': 62.32, 'duration': 4.64}, {'text': 'is the overall chassis rigid you can see', 'start': 64.799, 'duration': 3.521}, {'text': 'some like', 'start': 66.96, 'duration': 3.36}, {'text': "macro flexing here but that's the sort", 'start': 68.32, 'duration': 4.159}, {'text': 'of thing that like when the whole deck', 'start': 70.32, 'duration': 4.0}, {'text': "as one piece flexes you don't", 'start': 72.479, 'duration': 3.361}, {'text': 'necessarily get in the keys like yeah if', 'start': 74.32, 'duration': 2.96}, {'text': 'you look at the keys', 'start': 75.84, 'duration': 3.04}, {'text': "there's no deflection it's just if i'm", 'start': 77.28, 'duration': 5.12}, {'text': 'like really pushing it', 'start': 78.88, 'duration': 5.52}, {'text': 'okay the keyboard is great we also have', 'start': 82.4, 'duration': 3.92}, {'text': 'excellent key stabilization so you can', 'start': 84.4, 'duration': 4.079}, {'text': 'see here like if i push on the side of', 'start': 86.32, 'duration': 4.479}, {'text': 'the key the whole key goes down instead', 'start': 88.479, 'duration': 4.32}, {'text': 'of just like the corner going down', 'start': 90.799, 'duration': 3.28}, {'text': "that's the sort of thing that allows you", 'start': 92.799, 'duration': 3.121}, {'text': 'to have just a really fast typing', 'start': 94.079, 'duration': 4.321}, {'text': 'experience not have to kind of make sure', 'start': 95.92, 'duration': 4.08}, {'text': "that you're hitting the keys as opposed", 'start': 98.4, 'duration': 3.759}, {'text': 'to just hitting the keys now as well as', 'start': 100.0, 'duration': 4.64}, {'text': "having a fantastic keyboard it's also", 'start': 102.159, 'duration': 4.161}, {' ...
#                                          text    start  duration
# 0    all right guys hardest part of the video    0.080     2.960
# 1     we're getting it right out right out of    1.680     3.360
# 2     the gate i need to say the name of this    3.040     4.640
# 3          laptop correctly this sponsored by    5.040     3.920
# 4                            lenovo of course    7.680     5.200
# ..                                        ...      ...       ...
# 329                      a good laptop anyway  741.040     4.640
# 330  but yeah if you guys want to purchase it  743.120     4.719
# 331  links will be down below and just have a  745.680     4.399
# 332     fantastic day hit like get subscribed  747.839     4.641
# 333                                   so long  750.079     2.401
#
# [334 rows x 3 columns]
# [{'text': "all right tech family today we're going", 'start': 0.08, 'duration': 4.4}, {'text': 'to find the best premium powerful', 'start': 2.48, 'duration': 4.399}, {'text': '14-inch laptop that you can buy', 'start': 4.48, 'duration': 4.56}, {'text': '14-inch laptops are my personal favorite', 'start': 6.879, 'duration': 4.241}, {'text': 'form factor they are the laptops that', 'start': 9.04, 'duration': 3.44}, {'text': 'are large enough to have powerful', 'start': 11.12, 'duration': 3.76}, {'text': 'components inside and a display big', 'start': 12.48, 'duration': 4.879}, {'text': "enough to get real work done yet they're", 'start': 14.88, 'duration': 4.08}, {'text': 'still portable', 'start': 17.359, 'duration': 3.84}, {'text': 'let me introduce you to the contenders', 'start': 18.96, 'duration': 5.44}, {'text': 'first the asus g14 for 2022 specs on', 'start': 21.199, 'duration': 4.16}, {'text': 'screen', 'start': 24.4, 'duration': 3.76}, {'text': "next i've got the new yoga slim7 pro x", 'start': 25.359, 'duration': 5.201}, {'text': "the intel model there's also an amd", 'start': 28.16, 'duration': 4.48}, {'text': 'model available by the way and of course', 'start': 30.56, 'duration': 4.48}, {'text': "i've got the macbook pro 14 and the", 'start': 32.64, 'duration': 5.36}, {'text': 'razer blade 14 for 2022 which my good', 'start': 35.04, 'duration': 5.44}, {'text': 'friends at b h sent me for review', 'start': 38.0, 'duration': 4.64}, {'text': "as per usual this video isn't sponsored", 'start': 40.48, 'duration': 4.0}, {'text': "and i'm not getting paid by any of these", 'start': 42.64, 'duration': 3.2}, {'text': 'manufacturers', 'start': 44.48, 'duration': 3.44}, {'text': 'you might notice one premium 14 inch', 'start': 45.84, 'duration': 5.44}, {'text': "laptop is missing dell's alienware x14", 'start': 47.92, 'duration': 5.04}, {'text': "it just wasn't out in time when i", 'start': 51.28, 'duration': 4.0}, {'text': "started testing these machines i'm not", 'start': 52.96, 'duration': 4.64}, {'text': 'going to go into every minute detail of', 'start': 55.28, 'duration': 4.48}, {'text': 'these laptops it would be way too big a', 'start': 57.6, 'duration': 4.639}, {'text': 'video plus other reviewers have already', 'start': 59.76, 'duration': 4.719}, {'text': "done that instead i'm just going to talk", 'start': 62.239, 'duration': 4.481}, {'text': "about what it's like to own and use each", 'start': 64.479, 'duration': 4.561}, {'text': 'of these devices focusing on the things', 'start': 66.72, 'duration': 4.24}, {'text': 'that i believe matter the most when', 'start': 69.04, 'duration': 3.439}, {'text': 'choosing between them', 'start': 70.96, 'duration': 4.24}, {'text': "and by the way i've used these a lot", 'start': 72.479, 'duration': 4.721}, {'text': "i've edited videos for this channel on", 'start': 75.2, 'duration': 4.08}, {'text': "them i've played games on them i've done", 'start': 77.2, 'duration': 4.559}, {'text': 'work on them you get the picture when it', 'start': 79.28, 'duration': 4.879}, {'text': 'comes to the displays all these laptops', 'start': 81.759, 'duration': 4.481}, {'text': 'have very good ones they are all high', 'start': 84.159, 'duration': 4.561}, {'text': 'resolution high refresh rate panels if i', 'start': 86.24, 'duration': 4.96}, {'text': 'had to rate them the macbook pro 14 has', 'start': 88.72, 'duration': 4.32}, {'text': 'the best all-round display and the most', 'start': 91.2, 'duration': 4.64}, {'text': 'useful its bright high refresh rate mini', 'start': 93.04, 'duration': 4.8}, {'text': 'led panel allowed me to see more', 'start': 95.84, 'duration': 3.84}, {'text': 'information on screen than any other', 'start': 97.84, 'duration': 4.0}, {'text': 'laptop you can see that demonstrated in', 'start': 99.68, 'duration': 4.32}, {'text': 'my test of how many rows of excel i can', 'start': 101.84, 'duration': 4.639}, {'text': 'see on screen without needing to squint', 'start': 104.0, 'dur ...
#                                          text     start  duration
# 0     all right tech family today we're going     0.080     4.400
# 1           to find the best premium powerful     2.480     4.399
# 2             14-inch laptop that you can buy     4.480     4.560
# 3    14-inch laptops are my personal favorite     6.879     4.241
# 4       form factor they are the laptops that     9.040     3.440
# ..                                        ...       ...       ...
# 512     of effort that goes into making these  1145.600     4.319
# 513    but as i always say it makes my mother  1147.280     5.040
# 514           very proud till next time go do  1149.919     4.000
# 515     something awesome with your day and i  1152.320     5.200
# 516                      will catch you later  1153.919     3.601
#
# [517 rows x 3 columns]

# %%
OPENAI_API_KEY = "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"
loader = DirectoryLoader(path='./', glob = "**/*.txt", loader_cls=TextLoader,
                         show_progress=True)
docs = loader.load()
docs
# Out:
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# [Document(page_content="all right guys hardest part of the video\nwe're getting it right out right out of\nthe gate i need to say the name of this\nlaptop correctly this sponsored by\nlenovo of course\nis the lenovo slim 7i pro x not the yoga\nit is in europe but not here\nthe charger that we get is a hundred\nwatts over usb type-c really like to see\nit i thought at first when i saw that it\nwas yellow it was lenovo's little\nproprietary charger which also in\nfairness is pretty good all right what\nelse do we have in here\nit says yoga rate on it\nthe good news is it's a good feeling\nlaptop having a look at the i o here you\nget two thunderbolt 4 ports and you\nmight want to use those for display as\nwell because the hdmi we have right here\nis only 2.0 not 2.1 so if you're hooking\nup to 4k display and just use\nthunderbolts over on the other side we\nhave a full size usb type a headphone\nmicrophone combo and oh a little webcam\ndisabled i'd like to see that overall\nthough this is um a very laptop looking\nlaptop what i am impressed with though\nis the overall chassis rigid you can see\nsome like\nmacro flexing here but that's the sort\nof thing that like when the whole deck\nas one piece flexes you don't\nnecessarily get in the keys like yeah if\nyou look at the keys\nthere's no deflection it's just if i'm\nlike really pushing it\nokay the keyboard is great we also have\nexcellent key stabilization so you can\nsee here like if i push on the side of\nthe key the whole key goes down instead\nof just like the corner going down\nthat's the sort of thing that allows you\nto have just a really fast typing\nexperience not have to kind of make sure\nthat you're hitting the keys as opposed\nto just hitting the keys now as well as\nhaving a fantastic keyboard it's also\nnot the laptop we're supposed to be\nlooking at make sense uh this one's the\ngray this one right here is the teal\nalso this one does not say yoga right\nhere just says lenovo what i find\ninteresting though is that the displays\nare not the same on paper they're the\nsame but in\nreal life they obviously are not now\nthey both are 120 hertz panel they also\nhave a color calibrated from the factory\ni think it's what delta e of less than\none that is mangled good so you can\ndefinitely use this for your lightroom\nor video editing or what you have you\njust what i don't get is that the us\nmodel is glossy and the european appears\nto be matte the glossy one\nclearly has just nicer more vibrant\ncolors like the blacks look darker the\ncolors just look a little bit more\ncolorful but at the same time i can see\nmy face in it if i want to whereas the\nmac display does an exceptional job of\nnot showing me all the crap that's\naround me but at the same time you know\nit's just a little bit more washed up\nespecially with their great big light\nthat's above my head you don't think any\nof them are touch well\ni think you're wrong\nwait what this one not touch for\nwhatever reason\nthe one with the matte display does not\nhave touch and the one with the glossy\nscreen does have touch so before i was\nkind of leaning towards the matte\ndisplay because you know that's nice\ntouch is way better i absolutely love\ntouching a laptop especially one that's\ndisliked how much does this thing weigh\nstarts at 3.2 pounds damn that's really\ngood\nnow 3.2 pounds might not sound like the\nlightest thing ever there's much lighter\nlaptops out there the reason that's\nimpressive is because of the specs of\nthis thing oh damn that is really\nimpressive we have an intel i7 12700h\nnot even the p they just give you the\nfull fat 14 core 20 thread monster damn\nthis thing has 32 gigabytes of ram at\n1600 megahertz ddr5 okay i'm\nlegitimately impressed right now i\ndidn't look at this before i assumed it\nwas like a p series we also have one\nterabyte ssd intel wi-fi 6e iris xc\ngraphics of course\nbut you'll never use those because it\nalso has an rtx 3050. okay this one's a\nbit more r ...
#  Document(page_content="all right tech family today we're going\nto find the best premium powerful\n14-inch laptop that you can buy\n14-inch laptops are my personal favorite\nform factor they are the laptops that\nare large enough to have powerful\ncomponents inside and a display big\nenough to get real work done yet they're\nstill portable\nlet me introduce you to the contenders\nfirst the asus g14 for 2022 specs on\nscreen\nnext i've got the new yoga slim7 pro x\nthe intel model there's also an amd\nmodel available by the way and of course\ni've got the macbook pro 14 and the\nrazer blade 14 for 2022 which my good\nfriends at b h sent me for review\nas per usual this video isn't sponsored\nand i'm not getting paid by any of these\nmanufacturers\nyou might notice one premium 14 inch\nlaptop is missing dell's alienware x14\nit just wasn't out in time when i\nstarted testing these machines i'm not\ngoing to go into every minute detail of\nthese laptops it would be way too big a\nvideo plus other reviewers have already\ndone that instead i'm just going to talk\nabout what it's like to own and use each\nof these devices focusing on the things\nthat i believe matter the most when\nchoosing between them\nand by the way i've used these a lot\ni've edited videos for this channel on\nthem i've played games on them i've done\nwork on them you get the picture when it\ncomes to the displays all these laptops\nhave very good ones they are all high\nresolution high refresh rate panels if i\nhad to rate them the macbook pro 14 has\nthe best all-round display and the most\nuseful its bright high refresh rate mini\nled panel allowed me to see more\ninformation on screen than any other\nlaptop you can see that demonstrated in\nmy test of how many rows of excel i can\nsee on screen without needing to squint\nalso if you're like me and are worried\nabout the notch prior to owning a\nmacbook don't be\nas i said in my long term review of this\nlaptop you honestly just don't see it\nafter a while i'll link that video down\nbelow by the way next it's a tie between\nthe asus g14 and the slim7x pro for\ndifferent reasons the g14 is a joy to\nlook at it is super bright with\nexcellent color accuracy the fact that\nit's matte non-reflective makes it look\neven brighter than it is\nthat being said i couldn't comfortably\nsee nearly as much content as i could on\nthe slim 7 pro x's larger 14.5 inch\ndisplay the slim7 pro x has excellent\ncontrast and a fast refresh rate panel\nhowever it doesn't quite have the color\naccuracy of the other displays nor does\nit have the pop of an oled or mini led\npanel\nlast spot goes to the race at blade 14\nits display is the dimmest of the bunch\ni was regularly trying to hit the\nbrightness up key in the hopes of\ngetting more brightness out of it it's\nalso the only one with a 16 by 9 aspect\nratio so you see less information going\ndown the screen\nin my excel test i did see a couple more\nrows of excel than on the g14 which is a\nbit of a rounding error and is mainly\ndue to the mapping of windows scaling\nsettings to the pixel density of each\ndisplay i found with the g14 in\nparticular i was actually jumping\nbetween the scaling shown on screen and\none which made everything a bit smaller\nand allowed me to see more information\nthan the razer blade\ni do feel razer missed the opportunity\nto put a larger 16 by 10 aspect ratio\nscreen in this laptop just look at all\nthe wasted space where the bezel is\nbelow the screen the keyboard is an\noutright win for the g14 it is the most\ncomfortable laptop keyboard i've ever\nused next up is a type between the\nmacbook pro 14 and the slim 7 pro x\nboth of these have very comfortable\nkeyboards but you can still feel that\nthey are a little low travel which is\nnot something you notice on the g14\ndead last is the razer blade 14. i and\nother reviewers have been saying this\nfor years\nthis keyboard feels uncomfortably low\ntravel you really notice your fingers\nhitting t ...

# %%
index = VectorstoreIndexCreator(embedding=OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)).from_loaders([loader])
# Out:
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')).

# %%
question = input("Question: ")
result = index.query(f'{question}', llm=OpenAI(temperature=0, openai_api_key=OPENAI_API_KEY))
print(result)
